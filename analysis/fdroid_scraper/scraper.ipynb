# %%
import os
from time import sleep
from bs4 import BeautifulSoup
from requests import get
from model.model import ApplicationInfo, PackageSummary
from typing import List
import random
import csv
def save(content, path):
    print("Saving", f"/{path}")
    dirname = os.path.dirname(path)
    if not os.path.exists(dirname):
        os.makedirs(dirname)
    with open(path, 'wb') as file:
        file.write(content)

# Download and save
root_page = "https://f-droid.org"
RANDOM_STATE = 15

# %%
def page_has_next(soup: BeautifulSoup):
    browse_navigation = soup.find("ul", {"class": "browse-navigation"})
    return False if browse_navigation.select_one("li.next.disabled") else True

# %%
def save_categories():
    resp = get(f"{root_page}/en/packages/", timeout=5)
    html = resp.text
    soup = BeautifulSoup(html, features='lxml')
    all_links = []
    for link in soup.find_all('a'):
        all_links.append(link.get('href'))
    # filter by category
    categories = [link for link in all_links if 'categories' in link]
    print(categories)
    for cat in categories:
        soup = hit_and_save_category(cat)
        current_page = 1
        while page_has_next(soup):
            current_page += 1
            soup = hit_and_save_category(cat, current_page)

def wait_and_jitter(seconds):
    # wait for some seconds + a little jitter
    # that goes from 0 to half the seconds provided.
    rng = random.Random(RANDOM_STATE)
    jitter = seconds * 0.5 * rng.random()
    seconds_and_jitter = seconds + jitter
    sleep(seconds_and_jitter)

def hit_and_save_category(cat, page=1):
    wait_and_jitter(2)
    category_name = cat.split("/")[-2]
    file_name = category_name
    if page > 1:
        page_to_hit = f"{root_page}/en/categories/{category_name}/{page}"
        file_name += f"_{page}"
    else:
        page_to_hit = f"{root_page}{cat}"
    print(f"Hitting {page_to_hit}")
    resp = get(page_to_hit, timeout=10)
    soup = BeautifulSoup(markup=resp.text, features='lxml')
    save(soup.prettify(encoding='utf-8'), f"categories/{category_name}/{file_name}.html")
    return soup

# %%
# save_categories()

# %%
def get_applications_from_category_list(html: BeautifulSoup) -> List[dict]:
    package_list = html.find("div", {"id": "package-list"})
    package_list = package_list.find_all("a", {"class": "package-header"})
    parsed_packages = []
    for package in package_list:
        if isinstance(package, str):
            continue
        name = package.find("h4").get_text().strip()
        link = f"{root_page}{package.get('href').strip()}"
        summary = package.find("span").get_text().strip()
        package_name = link.split("/")[-2]
        parsed_packages.append(dict(name=name, summary=summary, link=link, package=package_name))
    return parsed_packages

def get_package_info(html: BeautifulSoup):
    author_name = None
    author_contact = None
    license = None
    license_page = None
    website = None
    issue_tracker = None
    source_code = None
    build_metadata = None
    for li in html.find_all("li"):
        text = li.get_text()
        if "author" in text.lower():
            author_contact = li.find("a").get("href")
            author_name = [t for t in text.replace("\t", "").split("\n") if t][-1]
        elif "license" in text.lower():
            license = [t for t in text.replace("\t", "").split("\n") if t][-1]
            license_page = li.find("a").get("href")
        else:
            anchor = li.find("a")
            anchor_link = anchor.get("href")
            anchor_text = anchor.get_text()
            if "website" in anchor_text.lower():
                website = anchor_link
            elif "issue tracker" in anchor_text.lower():
                issue_tracker = anchor_link
            elif "source code" in anchor_text.lower():
                source_code = anchor_link
            elif "build metadata" in anchor_text.lower():
                build_metadata = anchor_link
    return {
        "author": author_name,
        "author_contact": author_contact,
        "license": license,
        "license_page": license_page,
        "website": website,
        "issue_tracker": issue_tracker,
        "source_code": source_code,
        "build_metadata": build_metadata
    }

def get_application_info_from_package_page(html) -> dict:
    package_links = html.find("ul", {"class": "package-links"})
    info = get_package_info(package_links)
    return info

# %%
def extract_apps_and_save():
    packages: List[PackageSummary] = []
    for dirpath, cat_dirs, filenames in os.walk("categories"):
        htmls_filenames = [f for f in filenames if f.endswith(".html")]
        category = dirpath.split("/")[-1]
        print("extracting", category)
        if not htmls_filenames:
            continue
        for filename in htmls_filenames:
            file_to_open = f"{dirpath}/{filename}"
            with open(file_to_open, "r") as html_file:
                soup = BeautifulSoup(html_file.read(), features="lxml")
                try:
                    applications = get_applications_from_category_list(soup)
                except:
                    print("Error on file: ", file_to_open)
                    raise "!"
                pac = [
                    PackageSummary(
                        app["name"], app["package"], app["summary"], category, app["link"]
                    )
                    for app in applications
                ]
                packages.extend(pac)
    # save csv
    print("Saving CSV...")
    path = "output/fdroid_apps_list.csv"
    dirname = os.path.dirname(path)
    if not os.path.exists(dirname):
        os.makedirs(dirname)
    with open(path, "w") as csv_file:
        fields = ["name", "package", "summary", "category", "link"]
        writer = csv.DictWriter(csv_file, fieldnames=fields)
        writer.writeheader()
        for package in packages:
            writer.writerow(package.to_dict())

# %%
def get_complete_info(start_after: str = ""):
    first_line = True
    buffer = []
    with open("output/fdroid_apps_list.csv") as csv_file:
        apps = csv.DictReader(csv_file)
        should_skip = True if start_after else False
        for app in apps:
            # skip all apps until start_from
            if should_skip:
                first_line = False
                print("skipping", app["package"])
                if app["package"] == start_after:
                    should_skip = False
                continue
            # hit page
            print("Hitting package", app["package"], f"({app['link']})")
            resp = get(app["link"], timeout=5)
            if not resp.ok:
                print("Response NOT OK for", app["link"])
                raise Exception("NOT OK")
            html = resp.text
            soup = BeautifulSoup(html, features="lxml")
            info = get_application_info_from_package_page(soup)
            merged = app | info
            buffer.append(merged)
            if len(buffer) >= 10:
                with open("output/fdroid_apps_list_complete.csv", "a") as csv_file:
                    print("Saving CSV...")
                    example = buffer[0]
                    writer = csv.DictWriter(csv_file, fieldnames=example.keys())
                    if first_line == True:
                        first_line = False
                        writer.writeheader()
                    writer.writerows(buffer)
                    buffer.clear()
            wait_and_jitter(1)
    print("Done")

# %%
get_complete_info(start_after="eu.veldsoft.tri.peaks")
# Out:
# skipping net.bitconomy.ckpoolwatcher
# skipping com.mattallen.loaned
# skipping com.repay.android
# skipping org.moparisthebest.pageplus
# skipping com.veken0m.bitcoinium
# skipping wb.receiptspro
# skipping ee.smkv.calc.loan
# skipping org.tryton.client
# skipping com.nanoconverter.zlab
# skipping org.billthefarmer.specie
# skipping org.billthefarmer.currency
# skipping hashengineering.groestlcoin.wallet_test
# skipping hashengineering.groestlcoin.wallet
# skipping com.tombursch.kitchenowl
# skipping net.stargw.fx
# skipping com.agoradesk.app
# skipping co.localmonero.app
# skipping com.igisw.openmoneybox
# skipping com.coinerella.peercoin
# skipping me.hackerchick.catima
# skipping io.horizontalsystems.bankwallet
# skipping org.encointer.wallet
# skipping org.totschnig.myexpenses
# skipping com.invoiceninja.app
# skipping com.cosmos.candle
# skipping net.taler.wallet.fdroid
# skipping com.btcontract.wallet
# skipping com.starry.greenstash
# skipping de.salomax.currencies
# skipping de.chaosdorf.meteroid
# skipping ua.com.radiokot.lnaddr2invoice
# skipping com.cointrend
# skipping wtf.nbd.obw
# skipping net.ktnx.mobileledger
# skipping com.spencerpages
# skipping org.btcmap
# skipping com.greenaddress.greenbits_android_wallet
# skipping net.taler.merchantpos
# skipping com.brentpanther.bitcoinwidget
# skipping com.nishantboro.splititeasy
# skipping com.greenaddress.abcore
# skipping org.safecoin.safeprice
# skipping protect.budgetwatch
# skipping network.ubic.ubic
# skipping com.github.samotari.cryptoterminal
# skipping eu.uwot.fabio.altcoinprices
# skipping de.php_tech.piggybudget
# skipping me.kuehle.carreport
# skipping com.simpledecredwidget
# skipping de.blocklink.pigrid
# skipping protect.rentalcalc
# skipping org.elijaxapps.androidxmrigminer
# skipping com.eletac.tronwallet
# skipping com.outdoordevs.ellaism.wallet
# skipping com.vgorcum.minedmonero
# skipping com.brentpanther.litecoinwidget
# skipping com.brentpanther.ethereumwidget
# skipping protect.gift_card_guard
# skipping com.notriddle.budget
# skipping com.alaskalinuxuser.justcraigslist
# skipping ru.valle.btc
# skipping tmendes.com.analyticalbalancedroid
# skipping de.k4ever.k4android
# skipping mobi.boilr.boilr
# skipping net.alaindonesia.silectric
# skipping de.cryptobitch.muelli.vouchercalc
# skipping ivl.android.moneybalance
# skipping de.bitsharesmunich.wallet
# skipping it.greenaddress.cordova
# skipping de.cloneapps.crypto_prices
# skipping com.willchan.simple_random_stock
# skipping xyz.hisname.fireflyiii
# skipping net.eneiluj.moneybuster
# skipping co.timsmart.vouchervault
# skipping com.jstephan.yarc
# skipping com.oriondev.moneywallet
# skipping org.walleth
# skipping com.soumikshah.investmenttracker
# skipping com.pvcodes.debtcalc
# skipping com.lako.walletcount
# skipping com.cohenchris.weeklybudget
# skipping org.dash.electrum.electrum_dash
# skipping hashengineering.darkcoin.wallet
# skipping io.lbry.browser
# skipping com.emmanuelmess.simpleaccounting
# skipping com.decred.decredaddressscanner
# skipping com.flasskamp.subz
# skipping com.lightning.walletapp
# skipping com.github.samotari.paynoway
# skipping de.langerhans.wallet
# skipping net.nitratine.priceperunit
# skipping org.jdfossapps.android.shopwithmom
# skipping com.arduia.expense
# skipping com.xvzan.simplemoneytracker
# skipping app.crescentcash.src
# skipping protect.card_locker
# skipping info.tangential.cone
# skipping de.koelle.christian.trickytripper
# skipping org.weilbach.splitbills
# skipping org.bitbucket.watashi564.combapp
# skipping org.asafonov.monly
# skipping com.blogspot.e_kanivets.moneytracker
# skipping com.inator.calculator
# skipping de.varengold.activeTAN
# skipping im.status.ethereum
# skipping fr.corenting.convertisseureurofranc
# skipping com.jerameeldelosreyes.sushi
# skipping com.eurokonverter
# skipping com.marv42.ebt.newnote
# skipping de.schildbach.wallet_test
# skipping de.schildbach.wallet
# skipping com.pvpc.precio_luz
# skipping org.secuso.privacyfriendlyfinancemanager
# skipping ademar.bitac
# skipping org.ebur.debitum
# skipping com.tkton.wallet
# skipping com.ebaschiera.triplecamel
# skipping com.minimalisticapps.priceconverter
# skipping nitezh.ministock
# skipping com.nighthawkapps.wallet.android
# skipping de.drhoffmannsoft.pizza
# skipping com.github.webierta.carfoin
# skipping de.freewarepoint.whohasmystuff
# skipping net.taler.cashier
# skipping com.velas.mobile_wallet
# skipping com.gitlab.uak.mobile_paper_wallet
# skipping com.kazispin.money_logs
# skipping org.biotstoiq.seshat
# skipping io.dahliaos.calculator
# skipping com.duckduckgo.mobile.android
# skipping com.cosmos.unreddit
# skipping cx.ring
# skipping com.zoffcc.applications.trifa
# skipping com.roozbehzarei.filester
# skipping org.quantumbadger.redreader
# skipping geddit.buzl.uk
# skipping com.dessalines.thumbkey
# skipping im.vector.app
# skipping com.porg.gugal
# skipping org.woheller69.omweather
# skipping info.plateaukao.einkbro
# skipping de.kaffeemitkoffein.tinyweatherforecastgermany
# skipping com.nextcloud.talk2
# skipping com.freerdp.afreerdp
# skipping ru.nsu.bobrofon.easysshfs
# skipping it.niedermann.nextcloud.tables
# skipping de.lukasneugebauer.nextcloudcookbook
# skipping com.perol.asdpl.play.pixivez.libre
# skipping com.mattermost.rnbeta
# skipping com.github.catfriend1.syncthingandroid
# skipping com.fabienli.dokuwiki
# skipping su.xash.husky
# skipping org.andstatus.app
# skipping com.jiaqifeng.hacki
# skipping com.fediphoto.lineage
# skipping com.etesync.syncadapter
# skipping com.cosmos.candle
# skipping com.alovoa.expo
# skipping np.com.binabh.basedcooking
# skipping org.wikipedia
# skipping net.kollnig.missioncontrol.fdroid
# skipping io.nekohasekai.sagernet.plugin.naive
# skipping eu.faircode.email
# skipping d.d.meshenger
# skipping com.w2sv.wifiwidget
# skipping com.vitorpamplona.amethyst
# skipping com.streetwriters.notesnook
# skipping com.ominous.quickweather
# skipping com.nononsenseapps.feeder
# skipping com.nextcloud.android.beta
# skipping com.infomaniak.mail
# skipping com.infomaniak.drive
# skipping com.glitterware.passy
# skipping com.github.libretube
# skipping com.github.lamarios.clipious
# skipping com.databag
# skipping com.celzero.bravedns
# skipping com.b44t.messenger
# skipping chat.fluffy.fluffychat
# skipping us.spotco.fennec_dos
# skipping org.telegram.messenger
# skipping org.mozilla.fennec_fdroid
# skipping org.forkgram.messenger
# skipping org.brightdv.boxbox
# skipping io.github.benderblog.traintime_pda
# skipping host.stjin.anonaddy
# skipping dev.lbeernaert.youhavemail
# skipping de.tutao.tutanota
# skipping com.nutomic.syncthingandroid
# skipping de.jugendhacker.xmppadmin
# skipping be.humanoids.webthingify
# skipping com.github.samotari.cryptoterminal
# skipping com.eventyay.organizer
# skipping de.thecode.lmd
# skipping com.tht.k3pler
# skipping org.droidtr.termbin
# skipping tk.giesecke.painlessmesh
# skipping com.atop
# skipping ai.susi
# skipping de.grobox.blitzmail
# skipping fi.bitrite.android.ws
# skipping com.tobykurien.google_news
# skipping community.peers.internetradio
# skipping io.github.hidroh.materialistic
# skipping de.perflyst.untis
# skipping org.bienvenidoainternet.app
# skipping org.floens.chan
# skipping com.afollestad.nocknock
# skipping de.digisocken.anotherrss
# skipping org.saiditnet.redreader
# skipping de.digisocken.reotwe
# skipping de.hu_berlin.eduroam
# skipping github.vatsal.easyweatherdemo
# skipping eu.quelltext.gita
# skipping com.scraperclub.android
# skipping org.itishka.pointim
# skipping org.basketbuilddownloader
# skipping net.syncthing.lite
# skipping fr.rhaz.ipfs.sweet
# skipping com.danhasting.radar
# skipping com.alovoa.alovoa
# skipping nl.viter.glider
# skipping io.kuenzler.whatsappwebtogo
# skipping io.github.domi04151309.home
# skipping com.pitchedapps.frost
# skipping org.echoline.drawterm
# skipping com.parishod.watomatic
# skipping com.twoeightnine.root.xvii
# skipping com.berdik.macsposed
# skipping io.vertretungsplan.client.android
# skipping com.sapuseven.untis
# skipping site.leos.setter
# skipping com.kolloware.hypezigapp
# skipping fr.chenry.android.freshrss
# skipping org.dkf.jmule
# skipping cz.vitskalicky.lepsirozvrh
# skipping horse.amazin.my.stratum0.statuswidget
# skipping com.krawieck.lemmur
# skipping eu.dfdx.jslab
# skipping com.wire
# skipping org.fsociety.vernet
# skipping org.yausername.dvd
# skipping ch.abertschi.adfree
# skipping com.github.axet.torrentclient
# skipping com.kidozh.discuzhub.fdroid
# skipping de.pixart.messenger
# skipping me.loyko.ronald.linkbox
# skipping org.biotstoiq.gophercle
# skipping com.artivain.reseaudiscord
# skipping com.manimarank.spell4wiki
# skipping de.freehamburger
# skipping be.ugent.zeus.hydra.open
# skipping io.simplelogin.android.fdroid
# skipping io.nekohasekai.sagernet.plugin.mieru
# skipping com.indieweb.indigenous
# skipping io.spaceapi.community.myhackerspace
# skipping free.rm.skytube.legacy.oss
# skipping liou.rayyuan.ebooksearchtaiwan
# skipping free.rm.skytube.oss
# skipping io.mrarm.irc
# skipping ch.abertschi.waterme.water_me
# skipping com.zfdang.zsmth_android
# skipping org.thosp.yourlocalweather
# skipping org.snikket.android
# skipping com.xrcbapp
# skipping org.stingle.photos
# skipping com.julij.arsovreme
# skipping slowscript.warpinator
# skipping org.ttrssreader
# skipping de.monocles.mail
# skipping com.akansh.fileserversuit
# skipping cc.kafuu.bilidownload
# skipping be.casperverswijvelt.unifiedinternetqs
# skipping ro.radioromaniaactualitati.podcasts
# skipping org.handmadeideas.floccus
# skipping org.equeim.tremotesf
# skipping io.github.danxi_dev.dan_xi
# skipping dev.yashgarg.qbit
# skipping de.baumann.browser
# skipping in.amfoss.raag
# skipping org.purple.smokestack
# skipping com.lavabit.pahoehoe
# skipping com.libreweatherrn
# skipping com.amanoteam.unalix
# skipping ca.snoe.deedum
# skipping io.nekohasekai.sagernet.plugin.brook
# skipping timur.webrtc.check
# skipping com.example.trigger
# skipping com.tachibana.downloader
# skipping com.iskrembilen.quasseldroid
# skipping com.pcinpact
# skipping org.proninyaroslav.libretorrent
# skipping com.stypox.mastercom_workbook
# skipping cz.martykan.forecastie
# skipping com.cookiegames.smartcookie
# skipping org.mazhuang.guanggoo
# skipping io.nekohasekai.sagernet.plugin.trojan_go
# skipping rs.ltt.android
# skipping de.vier_bier.habpanelviewer
# skipping ltd.evilcorp.atox
# skipping in.shick.diode
# skipping io.muetsch.anchrandroid
# skipping email.schaal.ocreader
# skipping io.github.chiver
# skipping org.fox.tttrss
# skipping de.thecode.android.tazreader
# skipping com.concept1tech.instalate
# skipping com.trianguloy.continuousDataUsage
# skipping org.transdroid.search
# skipping es.ideotec.wdnotes
# skipping com.viper.simplert
# skipping me.thanel.dank
# skipping com.manimarank.websitemonitor
# skipping com.example.TTime
# skipping org.decsync.sparss.floss
# skipping fr.mobdev.peertubelive
# skipping io.nekohasekai.anXray
# skipping com.tasomaniac.openwith.floss
# skipping org.bombusmod
# skipping com.readrops.app
# skipping me.austinhuang.caweather
# skipping cf.theonewiththebraid.guerrilla_mail
# skipping pro.oblivioncoding.fluffy_board
# skipping be.mygod.vpnhotspot.foss
# skipping com.mirfatif.mylocation
# skipping de.csicar.ning
# skipping org.midorinext.android
# skipping com.meteocool
# skipping org.proninyaroslav.libretrack
# skipping com.Sommerlichter.social
# skipping com.akdev.nofbeventscraper
# skipping is.binary.alcoholnow
# skipping fr.nanoy.dinomail_app
# skipping dev.msfjarvis.aps
# skipping ru.ra66it.updaterforspotify
# skipping me.zhanghai.android.textselectionwebsearch
# skipping xyz.adjutor.aniki
# skipping me.austinhuang.instagrabber
# skipping space.rocketnine.xenia
# skipping network.loki.messenger.fdroid
# skipping org.calyxinstitute.vpn
# skipping com.flxrs.dankchat
# skipping com.chesire.nekome
# skipping nl.moeilijkedingen.jellyfinaudioplayer
# skipping com.github.metacubex.clash.meta
# skipping network.mysterium.vpn
# skipping com.perflyst.twire
# skipping com.dar.nclientv2
# skipping com.windscribe.vpn
# skipping com.keylesspalace.tusky
# skipping org.atalk.android
# skipping net.i2p.android.router
# skipping com.wireguard.android
# skipping com.cheogram.android
# skipping im.quicksy.client
# skipping gq.kirmanak.mealient
# skipping eu.siacs.conversations
# skipping de.stephanlindauer.criticalmaps
# skipping com.tutpro.baresip
# skipping com.tutpro.baresip.plus
# skipping co.prestosole.clima
# skipping biz.binarysolutions.weatherusa
# skipping de.qwerty287.ftpclient
# skipping org.irmacard.cardemu
# skipping net.sourceforge.dibdib.android.dib2qm
# skipping moe.matsuri.lite
# skipping ie.equalit.ceno
# skipping de.wellenvogel.bonjourbrowser
# skipping com.github.ttl.manager
# skipping org.schabi.kiba
# skipping com.joshtwigg.cmus.droid
# skipping com.polipoid
# skipping com.vlath.beheexplorer
# skipping it.rignanese.leo.slimtwitter
# skipping fr.xtof54.mousetodon
# skipping org.lf_net.pgpunlocker
# skipping com.alaskalinuxuser.justcraigslist
# skipping org.asdtm.goodweather
# skipping com.danvelazco.fbwrapper
# skipping io.gresse.hugo.anecdote
# skipping org.surrel.facebooknotifications
# skipping de.hirtenstrasse.michael.lnkshortener
# skipping com.tttdevs.stncbookmarks
# skipping com.juliansparber.captiveportallogin
# skipping org.wikimedia.commons.wikimedia
# skipping com.geecko.QuickLyric
# skipping com.rastating.droidbeard
# skipping org.zephyrsoft.checknetwork
# skipping com.vuze.android.remote
# skipping com.pindroid
# skipping org.asdtm.fas
# skipping de.k4ever.k4android
# skipping tk.jordynsmediagroup.simpleirc.fdroid
# skipping atitel.com.todoer
# skipping com.oakley.fon
# skipping org.sugr.gearshift
# skipping eu.siacs.conversations.voicerecorder
# skipping aq.com.sharetobrowser
# skipping me.jakelane.wrapperforfacebook
# skipping org.developfreedom.logmein
# skipping com.weatherlight.elloshare
# skipping com.selbie.wrek
# skipping edu.cmu.cylab.starslinger.demo
# skipping com.radioreddit.android
# skipping net.haltcondition.anode
# skipping eu.e43.impeller
# skipping szelok.app.twister
# skipping de.serverfrog.pw.android
# skipping org.wroot.android.goldeneye
# skipping gr.ndre.scuttloid
# skipping it.andreascarpino.hostisdown
# skipping org.thialfihar.android.apg
# skipping com.poloure.simplerss
# skipping org.mariotaku.twidere.extension.twitlonger
# skipping org.emergent.android.weave
# skipping ch.dissem.android.drupal
# skipping com.github.nicolassmith.urlevaluator
# skipping com.piratebayfree
# skipping org.tint
# skipping com.intrications.android.sharebrowser
# skipping com.blippex.app
# skipping headrevision.BehatReporter
# skipping com.scar45.aokp.co.webviewer
# skipping org.mustard.android
# skipping kr.softgear.multiping
# skipping org.adblockplus.android
# skipping li.klass.fhem
# skipping org.mumod.android
# skipping de.wikilab.android.friendica01
# skipping de.sigfood
# skipping sun.bob.leela
# skipping me.alexghr.bulkshare.android.app2
# skipping damo.three.ie
# skipping com.jtechme.jumpgo
# skipping eu.devunit.fb_client
# skipping org.cipherdyne.fwknop2
# skipping free.rm.netcfgwidget
# skipping me.shrimadhavuk.watransmitter
# skipping com.passcard
# skipping me.hda.urlhda
# skipping im.r_c.android.clearweather
# skipping net.etuldan.sparss.floss
# skipping org.surrel.messengerbypasser
# skipping org.poirsouille.tinc_gui
# skipping nya.miku.wishmaster
# skipping io.davidar.tensor
# skipping org.totschnig.sendwithftp
# skipping com.morlunk.mumbleclient
# skipping com.Pau.ImapNotes2
# skipping jonas.tool.saveForOffline
# skipping ru.gelin.android.weather.notification.skin.whitetextplus
# skipping ru.gelin.android.weather.notification.skin.blacktextplus
# skipping ru.gelin.android.weather.notification.skin.blacktext
# skipping ru.gelin.android.weather.notification.skin.biggertext
# skipping indrora.atomic
# skipping com.fullscreen
# skipping com.github.redpanal.android
# skipping com.mgaetan89.showsrage
# skipping systems.byteswap.aiproute
# skipping com.googlecode.droidwall
# skipping com.frostwire.android
# skipping de.antonfluegge.android.yubnubwidgetadfree
# skipping org.qii.weiciyuan
# skipping org.tint.adblock
# skipping tritop.androidSLWCpuWidget
# skipping com.ivanvolosyuk.sharetobrowser
# skipping com.sputnik.wispr
# skipping org.wiktionary
# skipping org.sparkleshare.android
# skipping com.elektropepi.bootboi
# skipping com.mishiranu.dashchan
# skipping uk.org.boddie.android.weatherforecast
# skipping org.transdroid.full
# skipping me.ccrama.redditslide
# skipping eu.quelltext.mundraub
# skipping org.akvo.rsr.up
# skipping fr.gaulupeau.apps.InThePoche
# skipping science.itaintrocket.pomfshare
# skipping com.pjuu.otterdroid
# skipping bus.chio.wishmaster
# skipping com.android.adbkeyboard
# skipping mobi.meddle.wehe
# skipping org.transdroid.lite
# skipping net.gsantner.dandelior
# skipping com.github.vauvenal5.yaga
# skipping pw.thedrhax.mosmetro
# skipping com.github.niqdev.ipcam
# skipping io.nekohasekai.sagernet.plugin.pingtunnel
# skipping com.tobykurien.webapps
# skipping com.github.samotari.paynoway
# skipping sterrenburg.github.flutterhole
# skipping de.sirjofri.fingerlist
# skipping org.tigase.messenger.phone.pro
# skipping com.gitlab.terrakok.gitfox
# skipping tech.platypush.platypush
# skipping org.freedombox.freedombox
# skipping app.weatheroverview
# skipping org.mariotaku.twidere
# skipping com.thirtydegreesray.openhub
# skipping com.aurora.corona
# skipping au.com.wallaceit.reddinator
# skipping com.stealthcotper.networktools
# skipping com.adguard.android.contentblocker
# skipping com.vadimfrolov.duorem
# skipping tk.giesecke.disaster_radio
# skipping com.bernaferrari.changedetection
# skipping com.github.moko256.twitlatte
# skipping com.eventyay.attendee
# skipping com.aaronhalbert.nosurfforreddit
# skipping tn.creativeteam.newyoutubelistingapp
# skipping org.kde.ktrip
# skipping com.yassirh.digitalocean
# skipping nl.patrickkostjens.kandroid
# skipping fr.jnda.android.ipcalc
# skipping org.libre.agosto.p2play
# skipping com.bytesforge.linkasanote
# skipping org.seamapdroid
# skipping com.jtmcn.archwiki.viewer
# skipping de.r4md4c.gamedealz
# skipping com.csmarosi.wifiautoff
# skipping org.safecoin.safeprice
# skipping acr.browser.lightning
# skipping uk.ac.swansea.eduroamcat
# skipping com.dfa.hubzilla_android
# skipping jp.redmine.redmineclient
# skipping com.xabber.android
# skipping click.dummer.have_radiosion
# skipping com.uploadedlobster.PwdHash
# skipping org.savapage.android.print
# skipping com.leastauthority.destiny
# skipping com.nima.demomusix
# skipping com.ensoft.imgurviewer
# skipping com.MarcosDiez.shareviahttp
# skipping org.outline.android.client
# skipping com.asdoi.gymwen
# skipping eu.neilalexander.yggdrasil
# skipping com.marv42.ebt.newnote
# skipping ooo.akito.webmon
# skipping io.github.chronosx88.yggdrasil
# skipping com.plexer0.nitter
# skipping livio.rssreader
# skipping com.luk.saucenao
# skipping org.metabrainz.android
# skipping io.heckel.ntfy
# skipping eu.auct.twitter2nitter
# skipping godau.fynn.moodledirect
# skipping org.vi_server.androidudpbus
# skipping com.flasskamp.energize
# skipping com.cweb.messenger
# skipping ua.gardenapple.itchupdater
# skipping com.ebaschiera.triplecamel
# skipping corewala.gemini.buran
# skipping io.nekohasekai.sagernet
# skipping net.turtton.ytalarm
# skipping net.daverix.urlforward
# skipping me.tagavari.airmessage
# skipping org.disroot.disrootapp
# skipping com.odysee.floss
# skipping com.leestarb.fourthtools
# skipping bou.amine.apps.readerforselfossv2.android
# skipping de.monocles.chat
# skipping com.trianguloy.urlchecker
# skipping com.stoutner.privacybrowser.standard
# skipping asgardius.page.s3manager
# skipping org.proninyaroslav.opencomicvine
# skipping com.github.gotify
# skipping asgardius.page.s3music
# skipping org.pixeldroid.app
# skipping ml.docilealligator.infinityforreddit
# skipping it.niedermann.owncloud.notes
# skipping com.nyx.custom_uploader
# skipping com.in.my.district
# skipping de.metager.metagerapp.fdroid
# skipping org.purplei2p.i2pd
# skipping org.mian.gitnex
# skipping io.nekohasekai.sagernet.plugin.tuic
# skipping io.nekohasekai.sagernet.plugin.hysteria
# skipping io.mainframe.hacs
# skipping it.niedermann.nextcloud.deck
# skipping com.emanuelef.remote_capture
# skipping fr.free.nrw.commons
# skipping eu.faircode.netguard
# skipping de.luhmer.owncloudnewsreader
# skipping com.nextcloud.client
# skipping ru.yourok.torrserve
# skipping com.gianlu.aria2app
# skipping com.gianlu.aria2android
# skipping org.cryptomator.lite
# skipping org.btcmap
# skipping org.smblott.intentradio
# skipping net.gorry.aicia
# skipping com.malek.alldebrid
# skipping com.example.ismael.downloadfilesweb
# skipping com.thehoick.evergreenwishlist
# skipping com.btmura.android.reddit
# skipping co.loubo.icicle
# skipping org.kost.nmap.android.networkmapper
# skipping com.reddyetwo.hashmypass.app
# skipping com.xabber.android.classic
# skipping app.openconnect
# skipping io.github.mthli.Ninja
# skipping us.shandian.giga
# skipping gg.mw.passera
# skipping com.linuxcounter.lico_update_003
# skipping at.bitfire.cadroid
# skipping ru.gelin.android.browser.open
# skipping com.mill_e.twitterwrapper
# skipping com.lgallardo.qbittorrentclientpro
# skipping cs4295.memecreator
# skipping org.yaaic
# skipping ch.citux.td
# skipping net.bitconomy.ckpoolwatcher
# skipping com.isanexusdev.androidcpg
# skipping net.vreeken.quickmsg
# skipping org.macno.puma
# skipping net.dahanne.android.regalandroid
# skipping com.iven.xdafeedreader
# skipping sk.vx.connectbot
# skipping com.unwind.networkmonitor
# skipping de.tu_darmstadt.seemoo.HardWhere
# skipping com.ubergeek42.WeechatAndroid
# skipping de.idiomreplacex.browser_app
# skipping com.dx.anonymousmessenger
# skipping godau.fynn.dsbdirect
# skipping de.monocles.social
# skipping org.freenetproject.mobile
# skipping app.fedilab.nitterizemelite
# skipping app.fedilab.nitterizeme
# skipping app.fedilab.tubelab
# skipping app.fedilab.fedilabtube
# skipping org.openttd.fdroid
# skipping net.ibbaa.keepitup
# skipping dev.ukanth.ufirewall
# skipping se.lublin.mumla
# skipping com.kanedias.holywarsoo
# skipping org.itxtech.daedalus
# skipping wangdaye.com.geometricweather
# skipping app.intra
# skipping ru.evgeniy.dpitunnelcli
# skipping se.leap.riseupvpn
# skipping kuesji.link_eye.fdroid
# skipping org.ietf.ietfsched
# skipping se.leap.bitmaskclient
# skipping com.governikus.ausweisapp2
# skipping tech.techlore.plexus
# skipping moe.dic1911.urlsanitizer
# skipping site.xiaocao.pixiv
# skipping de.bwl.lfdi.app
# skipping pcmagas.vodafone_fu_h300s
# skipping app.fedilab.mobilizon
# skipping io.github.ismywebsiteup
# skipping telegra.ph
# skipping org.dystopia.email
# skipping com.fediphoto
# skipping com.biglybt.android.client
# skipping it.skarafaz.mercury
# skipping com.anoopknr.pastebin
# skipping com.zoffcc.applications.metalab_open_widget
# skipping org.deluge.trireme
# skipping de.baumann.weather
# skipping godau.fynn.bandcampdirect
# skipping net.guildem.publicip
# skipping android.nachiketa.ebookdownloader
# skipping com.dimtion.shaarlier
# skipping com.commit451.gitlab
# skipping nl.asymmetrics.droidshows
# skipping fr.guillaumevillena.opendnsupdater
# skipping tool.fff.profilepicturegenerator
# skipping ru.gelin.android.weather.notification
# skipping com.kolloware.wechange
# skipping de.freifunk_karte.freifunk_karte
# skipping com.github.shadowsocks.plugin.v2ray
# skipping org.kontalk
# skipping me.kavishhukmani.watwitchstickers
# skipping com.starapps.tools.tnefextractor
# skipping hu.tagsoft.ttorrent.search
# skipping org.freshrss.easyrss
# skipping me.zeeroooo.materialfb
# skipping com.mde.potdroid
# skipping com.jerboa
# skipping com.infomaniak.sync
# skipping com.github.k1rakishou.chan.fdroid
# skipping com.fsck.k9
# skipping ch.protonvpn.android
# skipping at.bitfire.davdroid
# skipping InfinityLoop1309.NewPipeEnhanced
# skipping org.schabi.newpipe
# skipping net.mullvad.mullvadvpn
# skipping de.spiritcroc.riotx
# skipping androdns.android.leetdreams.ch.androdns
# skipping uk.openvk.android.legacy
# skipping oss.krtirtho.spotube
# skipping org.nuclearfog.twidda
# skipping org.moire.ultrasonic
# skipping org.joinmastodon.android
# skipping net.slions.fulguris.full.fdroid
# skipping de.marmaro.krt.ffupdater
# skipping com.seafile.seadroid2
# skipping com.github.andreyasadchy.xtra
# skipping town.robin.toadua
# skipping com.geekorum.ttrss.free
# skipping org.woheller69.weather
# skipping org.woheller69.solxpect
# skipping org.pacien.tincapp
# skipping org.openobservatory.ooniprobe
# skipping org.openhab.habdroid.beta
# skipping de.blinkt.openvpn
# skipping net.gitsaibot.af
# skipping fr.gouv.etalab.mastodon
# skipping com.dosse.speedtest
# skipping org.sufficientlysecure.termbot
# skipping com.pavelsof.wormhole
# skipping ru.evgeniy.dpitunnel
# skipping org.jak_linux.dns66
# skipping taco.apkmirror
# skipping com.pato05.uploadgram
# skipping com.tobykurien.webmediashare
# skipping com.etesync.notes
# skipping org.strawberryforum.argentum
# skipping com.gmail.anubhavdas54.whatsdeleted
# skipping de.jonasbernard.tudarmstadtmoodlewrapper
# skipping org.shirakumo.ocelot
# skipping com.ruesga.rview
# skipping com.asdoi.mebis
# skipping org.galexander.sshd
# skipping org.poul.bits.android
# skipping io.github.subhamtyagi.openinwhatsapp
# skipping org.schabi.newpipelegacy
# skipping com.abhinavmarwaha.curator
# skipping net.mabako.steamgifts
# skipping net.inbox.pager
# skipping net.programmierecke.radiodroid2
# skipping sh.ikl.liteshort
# skipping ca.andries.portknocker
# skipping io.github.datastopwatch
# skipping fi.kroon.vadret
# skipping search.searx
# skipping com.github.dfa.diaspora_android
# skipping com.kanedias.archforums
# skipping com.nextcloud_cookbook_flutter
# skipping com.bikodbg.sharetopinboard
# skipping nekox.messenger
# skipping im.fdx.v2ex
# skipping de.beowulf.wetter
# skipping su.sadrobot.yashlang
# skipping ua.bossly.tools.translit
# skipping org.greatfire.wikiunblocked.fdroid
# skipping dnsfilter.android
# skipping com.github.livingwithhippos.unchained
# skipping tube.chikichiki.sako
# skipping org.connectbot
# skipping de.nucleus.foss_warn
# skipping org.strongswan.android
# skipping gov.anzong.androidnga
# skipping de.jbservices.nc_passwords_app
# skipping de.badaix.snapcast
# skipping com.czy0729.bangumi
# skipping de.monocles.browser
# skipping com.chao.app
# skipping com.github.shadowsocks.tv
# skipping com.coboltforge.dontmind.multivnc
# skipping ch.famoser.mensa
# skipping com.nunti
# skipping com.github.shadowsocks
# skipping org.stypox.dicio
# skipping cz.hernikplays.opencanteen
# skipping com.twidere.twiderex
# skipping com.nltechno.dolidroidpro
# skipping com.nima.wikianime
# skipping org.briarproject.briar.android
# skipping dev.bartuzen.qbitcontroller
# skipping com.gianlu.dnshero
# skipping it.davquar.halfdot
# skipping de.niendo.ImapNotes3
# skipping com.amrdeveloper.linkhub
# skipping org.softeg.slartus.forpdaplus
# skipping com.oF2pks.jquarks
# skipping org.openhab.habdroid
# skipping com.github.xfalcon.vhosts
# skipping com.gaurav.avnc
# skipping nl.eduvpn.app
# skipping com.zulipmobile
# skipping com.prostudio.urltopdfconverter
# skipping com.owncloud.android
# skipping fr.emersion.goguma
# skipping com.drnoob.datamonitor
# skipping at.finderlein.noe
# skipping com.torrents_csv_android
# skipping org.schabi.nxbookmarks
# skipping pan.alexander.tordnscrypt.stable
# skipping com.github.howeyc.crocgui
# skipping me.murks.feedwatcher
# skipping it.rignanese.leo.slimfacebook
# skipping com.blazecode.tsviewer
# skipping co.appreactor.news
# skipping chat.rocket.android
# skipping timur.webcall.callee
# skipping org.purple.smoke
# skipping com.jonjomckay.fritter
# skipping com.gmail.afonsotrepa.pocketgopher
# skipping org.opengappsdownloader
# skipping com.antoniotari.reactiveampacheapp
# skipping de.binary_kitchen.doorlock_app
# skipping org.yaxim.androidclient
# skipping com.weskenyon.bookmarkos
# skipping org.indywidualni.fblite
# skipping com.angryburg.uapp
# skipping com.nikhiljha.lobstersapp
# skipping cz.martykan.webtube
# skipping tyagi.shubham.customsearch
# skipping de.tobiasbielefeld.searchbar
# skipping in.andres.kandroid
# skipping de.vibora.viborafeed
# skipping org.lenchan139.ncbookmark
# skipping com.ames.books
# skipping org.poopeeland.tinytinyfeed
# skipping cz.jiriskorpil.amixerwebui
# skipping org.afhdownloader
# skipping de.live.gdev.timetracker
# skipping org.retroshare.android.qml_app
# skipping co.pxhouse.sas
# skipping fil.libre.repwifiapp
# skipping de.lihotzki.pixelflood
# skipping com.a5corp.weather
# skipping com.javiersantos.whatsappbetaupdater
# skipping de.live.gdev.cherrymusic
# skipping fr.mobdev.goblim
# skipping org.xposeddownloader
# skipping com.commonslab.commonslab
# skipping ua.com.radiokot.photoprism
# skipping com.shifthackz.aisdv1.app.foss
# skipping com.dede.android_eggs
# skipping com.simplemobiletools.gallery.pro
# skipping io.github.doubi88.slideshowwallpaper
# skipping org.jshobbysoft.cameraalign
# skipping com.perol.asdpl.play.pixivez.libre
# skipping site.leos.apps.lespas
# skipping org.catrobat.paintroid
# skipping com.burhanrashid52.photoediting
# skipping com.simplemobiletools.draw.pro
# skipping com.vincentengelsoftware.vesandroidimagecompare
# skipping deckers.thibault.aves.libre
# skipping ru.tech.imageresizershrinker
# skipping org.tuxpaint
# skipping io.github.freewatermark.mobileapp
# skipping com.zhenxiang.superimage
# skipping de.kaffeemitkoffein.imagepipe
# skipping com.exifthumbnailadder.app
# skipping io.github.gsantner.memetastic
# skipping de.k3b.android.lossless_jpg_crop
# skipping eu.quelltext.coloring
# skipping com.ero.kinoko
# skipping io.github.subhamtyagi.ocr
# skipping org.krita
# skipping com.nesbox.tic
# skipping troop.com.freedcam
# skipping fr.nuage.souvenirs
# skipping org.secuso.privacyfriendlysketching
# skipping mobi.omegacentauri.SendReduced
# skipping com.therealbluepandabear.pixapencil
# skipping screen.dimmer.pixelfilter
# skipping org.totschnig.ocr.tesseract
# skipping com.gluege.nightlight
# skipping org.andresoviedo.dddmodel2
# skipping de.kaffeemitkoffein.feinstaubwidget
# skipping pro.oblivioncoding.fluffy_board
# skipping com.benny.pxerstudio
# skipping com.github.vauvenal5.yaga
# skipping de.k3b.android.camerafolder
# skipping com.alienpants.leafpicrevived
# skipping anupam.acrylic
# skipping com.todobom.opennotescanner
# skipping com.dozingcatsoftware.asciicam
# skipping de.k3b.android.androFotoFinder
# skipping zen.meditation.android
# skipping org.piwigo.android
# skipping com.developerfromjokela.motioneyeclient
# skipping de.beatbrot.screenshotassistant
# skipping com.wrmndfzzy.atomize
# skipping de.digisocken.stop_o_moto
# skipping rodrigodavy.com.github.pixelartist
# skipping uk.co.richyhbm.monochromatic
# skipping com.gtp.showapicturetoyourfriend
# skipping org.atai.TessUI
# skipping us.koller.cameraroll
# skipping de.lihotzki.pixelflood
# skipping ch.jiikuy.velocitycalculator
# skipping org.voidptr.swpieview
# skipping com.tomer.draw
# skipping org.horaapps.leafpic
# skipping de.cryptobitch.muelli.barcodegen
# skipping com.easytarget.micopi
# skipping at.bitfire.gfxtablet
# skipping com.nathanosman.chronosnap
# skipping unisiegen.photographers.activity
# skipping org.androidsoft.coloring
# skipping cs4295.memecreator
# skipping com.code61.deadpixel
# skipping edu.sfsu.cs.orange.ocr
# skipping org.appsroid.fxpro
# skipping com.gmail.mugcuposup.android
# skipping org.dsandler.apps.markers
# skipping com.wentam.defcol
# skipping com.write.Quill
# skipping com.tmarki.comicmaker
# skipping org.zakky.memopad
# skipping com.gmail.altakey.effy
# skipping com.rj.pixelesque
# skipping com.xatik.app.droiddraw.client
# skipping net.tedstein.AndroSS
# skipping de.kromke.andreas.safmediascanner
# skipping com.secuso.privacyFriendlyCodeScanner
# skipping com.opencamera_sensors.app
# skipping fr.odrevet.bide_et_musique
# skipping com.zoffcc.applications.avifview
# skipping org.gateshipone.odyssey
# skipping org.gateshipone.malp
# skipping com.tnibler.cryptocam
# skipping de.kromke.andreas.musictagger
# skipping ru.natsuru.websdr
# skipping com.jesperh.showyoutubedislikes
# skipping org.github.henryquan.animeone
# skipping ac.robinson.mediaphone
# skipping com.reecedunn.espeak
# skipping de.kromke.andreas.unpopmusicplayerfree
# skipping dev.danjackson.speaker
# skipping org.witness.sscphase1
# skipping dev.danjackson.noisecancel
# skipping org.zephyrsoft.sdbviewer
# skipping com.subtracks
# skipping in.amfoss.raag
# skipping com.gluege.nightlight
# skipping net.schueller.peertube
# skipping github.daneren2005.dsub
# skipping com.tunerly
# skipping com.fredhappyface.ewesticker
# skipping org.proninyaroslav.blink_comparison
# skipping com.klee.volumelockr
# skipping org.andresoviedo.dddmodel2
# skipping de.salomax.muzei.thevergewallpapers
# skipping com.dkanada.gramophone
# skipping io.bmaupin.pitchpipe
# skipping com.github.livingwithhippos.unchained
# skipping org.videolan.vlc
# skipping tube.chikichiki.sako
# skipping org.phramusca.jamuz
# skipping de.k3b.android.lossless_jpg_crop
# skipping de.badaix.snapcast
# skipping com.czy0729.bangumi
# skipping com.agateau.catgenerator
# skipping ch.blinkenlights.android.vanilla
# skipping net.pmarks.chromadoze
# skipping io.gitlab.listentogether
# skipping info.dvkr.screenstream
# skipping com.martinmimigames.tinymusicplayer
# skipping net.reichholf.dreamdroid
# skipping de.thefeiter.liedgutverzeichnis
# skipping com.github.axet.hourlyreminder
# skipping com.cliffracertech.soundaura
# skipping com.nima.demomusix
# skipping org.musicpd
# skipping net.sourceforge.opencamera
# skipping org.krita
# skipping com.nesbox.tic
# skipping de.kromke.andreas.cameradatefolders
# skipping com.dozingcatsoftware.vectorcamera
# skipping groomiac.voicemailplayer
# skipping com.luk.saucenao
# skipping com.example.barcodescanner
# skipping org.metabrainz.android
# skipping se.embargo.retroboy
# skipping com.joshtwigg.cmus.droid
# skipping git.rrgb.kinolog
# skipping com.danielkim.soundrecorder
# skipping net.sourceforge.wifiremoteplay
# skipping ut.ewh.audiometrytest
# skipping re.jcg.playmusicexporter
# skipping org.wikimedia.commons.wikimedia
# skipping com.geecko.QuickLyric
# skipping info.aario.killcamera
# skipping pl.hypeapp.endoscope
# skipping jpf.android.magiadni
# skipping mbmb5.lumixextendedcontrolapp
# skipping click.dummer.rickapp
# skipping com.cleveroad.sample
# skipping org.secuso.privacyfriendlyruler
# skipping com.quaap.audiometer
# skipping com.smithdtyler.prettygoodmusicplayer
# skipping fr.s13d.photobackup
# skipping org.horaapps.leafpic
# skipping net.sf.ethersynth
# skipping com.workingagenda.fissure
# skipping com.sound.ampache
# skipping com.xperia64.timidityae
# skipping com.android.music
# skipping eu.flatworld.android.slider
# skipping net.majorkernelpanic.spydroid
# skipping com.saladdressing.veterondo
# skipping eu.faircode.finegeotag
# skipping vnd.blueararat.kaleidoscope6
# skipping de.bjusystems.vdrmanager
# skipping de.meonwax.soundboard
# skipping org.schabi.svgredirect
# skipping org.jamienicol.episodes
# skipping de.phoenixstudios.pc_dimmer
# skipping com.einmalfel.podlisten
# skipping com.dozingcatsoftware.cameratimer
# skipping org.mariotaku.imageviewergl
# skipping cc.rainwave.android
# skipping net.bitplane.android.microphone
# skipping org.tvheadend.tvhguide
# skipping com.github.redpanal.android
# skipping com.fastebro.androidrgbtool
# skipping fr.herverenault.directdictaphone
# skipping org.quovadit.apps.andof
# skipping fr.tvbarthel.apps.cameracolorpicker
# skipping kaljurand_at_gmail_dot_com.diktofon
# skipping com.yasfa.views
# skipping com.refactech.driibo
# skipping cat.jordihernandez.cinecat
# skipping github.yaa110.piclice
# skipping com.brillenheini.deepscratch.free
# skipping com.sevag.pitcha
# skipping com.jonbanjo.cupsprintservice
# skipping com.nathanosman.chronosnap
# skipping unisiegen.photographers.activity
# skipping it.reyboz.chordshift
# skipping fm.a2d.sf
# skipping com.turtleplayerv2
# skipping ch.citux.td
# skipping jp.co.kayo.android.localplayer.ds.podcast
# skipping mixedbit.speechtrainer
# skipping remuco.client.android
# skipping com.googlecode.chartdroid
# skipping ua.com.radiokot.photoprism
# skipping player.phonograph.plus
# skipping org.mosad.teapod
# skipping org.cimbar.camerafilecopy
# skipping miru.miaomint
# skipping me.timschneeberger.rootlessjamesdsp
# skipping io.ente.photos.fdroid
# skipping com.unicornsonlsd.finamp
# skipping com.qfs.pagan
# skipping com.maxrave.simpmusic
# skipping com.github.libretube
# skipping com.github.lamarios.clipious
# skipping la.daube.photochiotte
# skipping de.ph1b.audiobook
# skipping de.kromke.andreas.opus1musicplayer
# skipping com.podverse.fdroid
# skipping InfinityLoop1309.NewPipeEnhanced
# skipping org.schabi.newpipe
# skipping app.alextran.immich
# skipping oss.krtirtho.spotube
# skipping org.moire.ultrasonic
# skipping org.joinmastodon.android
# skipping io.github.zyrouge.symphony
# skipping com.github.andreyasadchy.xtra
# skipping com.caydey.ffshare
# skipping us.spotco.ir_remote
# skipping org.woheller69.TimeLapseCam
# skipping io.github.dlbeswick.kreuungching
# skipping com.atharok.barcodescanner
# skipping org.woheller69.audio_analyzer_for_android
# skipping org.dyndns.warenix.web2pdf
# skipping tkj.android.homecontrol.mythmote
# skipping ro.ciubex.dscautorename
# skipping cat.pantsu.nyaapantsu
# skipping com.alexkang.loopboard
# skipping com.stonegate.tsacdop
# skipping com.bytestemplar.tonedef
# skipping com.hardcodecoder.pulsemusic
# skipping com.dkanada.icecons
# skipping com.bri1.soundbored.reborn
# skipping tech.platypush.platypush
# skipping be.knars.netflixtoimdb
# skipping de.k3b.android.camerafolder
# skipping org.herac.tuxguitar.android.application
# skipping com.alienpants.leafpicrevived
# skipping com.pato05.uploadgram
# skipping com.tobykurien.webmediashare
# skipping com.listen1.app
# skipping com.cg.lrceditor
# skipping io.github.domi04151309.podscompanion
# skipping net.ebt.muzei.miyazaki
# skipping moe.martini.midictrl
# skipping com.nicolasbrailo.vlcfreemote
# skipping mn.tck.semitone
# skipping org.schabi.newpipelegacy
# skipping com.tistory.deque.previewmaker
# skipping ir.mrahimy.conceal
# skipping org.schabi.jedentageinset
# skipping net.programmierecke.radiodroid2
# skipping raffarti.simpleadvancedmetronome
# skipping eu.pretix.pretixprint
# skipping org.jellyfin.androidtv
# skipping com.poupa.vinylmusicplayer
# skipping com.bobek.metronome
# skipping org.hollowbamboo.chordreader2
# skipping org.courville.nova
# skipping org.billthefarmer.siggen
# skipping io.github.teccheck.fastlyrics
# skipping ml.docilealligator.infinityforreddit
# skipping de.taz.android.app.free
# skipping com.github.cvzi.screenshottile
# skipping org.billthefarmer.scope
# skipping com.iakmds.librecamera
# skipping com.vincentengelsoftware.vesandroidimagecompare
# skipping deckers.thibault.aves.libre
# skipping com.shadow.blackhole
# skipping is.xyz.mpv
# skipping de.ptrlx.oneshot
# skipping com.berkersen.practicesuite
# skipping swati4star.createpdf
# skipping org.jellyfin.mobile
# skipping org.billthefarmer.tuner
# skipping com.certified.audionote
# skipping io.github.freewatermark.mobileapp
# skipping com.utazukin.ichaival
# skipping com.prangesoftwaresolutions.audioanchor
# skipping de.markusfisch.android.binaryeye
# skipping it.zitzusoft.lyrics_2
# skipping com.bnyro.trivia
# skipping org.schabi.nxbookmarks
# skipping com.rohit2810.spotit
# skipping com.freshollie.monkeyboard.keystoneradio
# skipping com.matt.outfield
# skipping net.schueller.instarepost
# skipping com.kanedias.vanilla.audiotag
# skipping de.devmil.muzei.bingimageofthedayartsource
# skipping com.maxfour.music
# skipping com.github.cythara
# skipping godau.fynn.bandcampdirect
# skipping link.standen.michael.slideshow
# skipping com.github.niccokunzmann.hanumanchalisa
# skipping nl.asymmetrics.droidshows
# skipping com.thibaudperso.sonycamera
# skipping com.github.andremiras.qrscan
# skipping hu.tagsoft.ttorrent.search
# skipping com.kanedias.vanilla.coverfetch
# skipping jp.muo.syncmemories
# skipping net.nullsum.audinaut
# skipping com.dozingcatsoftware.asciicam
# skipping com.vadimfrolov.duorem
# skipping de.k3b.android.androFotoFinder
# skipping io.github.benoitduffez.cupsprint
# skipping me.murks.filmchecker
# skipping com.fr3ts0n.stagefever
# skipping a2dp.Vol
# skipping org.fitchfamily.android.symphony
# skipping de.qspool.clementineremote
# skipping tn.creativeteam.newyoutubelistingapp
# skipping org.libre.agosto.p2play
# skipping de.antonarnold.android.xoverrideheadphonejackdetection
# skipping mkg20001.net.samremote
# skipping max.music_cyclon
# skipping org.notabug.lifeuser.moviedb
# skipping com.google.zxing.client.android
# skipping org.mcxa.softsound
# skipping cz.martykan.webtube
# skipping pt.ipleiria.mymusicqoe
# skipping org.atai.TessUI
# skipping com.redirectapps.tvkill
# skipping pk.contender.earmouse
# skipping us.achromaticmetaphor.imcktg
# skipping protect.babysleepsounds
# skipping com.jvillalba.apod.md
# skipping com.jvillalba.apod.classic
# skipping org.libreflix.app
# skipping com.ames.books
# skipping us.koller.cameraroll
# skipping cz.jiriskorpil.amixerwebui
# skipping org.bottiger.podcast
# skipping felixwiemuth.lincal
# skipping ch.jiikuy.velocitycalculator
# skipping net.opendasharchive.openarchive.release
# skipping de.live.gdev.cherrymusic
# skipping com.arnaud.metronome
# skipping net.chilon.matt.teacup
# skipping com.namelessdev.mpdroid
# skipping com.commonslab.commonslab
# skipping org.bitbucket.tickytacky.mirrormirror
# skipping com.ringdroid
# skipping atm.nasaimages
# skipping com.soyblue.bluesound
# skipping com.callrecorder.android
# skipping com.isdp.trirose
# skipping net.rocboronat.android.wallpaper.npe
# skipping com.isanexusdev.androidcpg
# skipping com.smithdtyler.prettygoodmusicplayer.launchermode
# skipping com.claha.showtimeremote
# skipping com.jparkie.aizoban
# skipping com.falconware.prestissimo
# skipping tv.piratemedia.lightcontroler
# skipping teaonly.droideye
# skipping net.phunehehe.foocam
# skipping jupiter.broadcasting.live.tv
# skipping org.kaziprst.android.ndfilter
# skipping com.flipcamera
# skipping com.gmail.mugcuposup.android
# skipping com.radiostudent.radiostudentstream
# skipping org.numixproject.iconsubmit
# skipping com.selbie.wrek
# skipping com.mattallen.dpixel
# skipping com.tjm.stripepaper
# skipping com.kure.musicplayer
# skipping edu.cmu.pocketsphinx.demo
# skipping com.ssaurel.clocklw
# skipping com.unwrappedapps.android.wallpaper.creative
# skipping net.sourceforge.subsonic.androidapp
# skipping com.call.recorder
# skipping net.stkaddons.viewer
# skipping fr.xplod.focal
# skipping com.jadn.cc
# skipping com.github.axet.audiorecorder
# skipping me.rosuh.easywatermark
# skipping com.simplemobiletools.gallery.pro
# skipping com.gokadzev.musify.fdroid
# skipping geddit.buzl.uk
# skipping de.christinecoenen.code.zapp
# skipping org.koitharu.kotatsu
# skipping com.simplemobiletools.camera
# skipping com.tuntori.mightieramp
# skipping com.simplemobiletools.musicplayer
# skipping com.serwylo.babydots
# skipping com.illusionman1212.lyricsgrabbr
# skipping com.perol.asdpl.play.pixivez.libre
# skipping com.martinmimigames.littlemusicplayer
# skipping com.simplemobiletools.calendar.pro
# skipping nl.moeilijkedingen.jellyfinaudioplayer
# skipping com.brouken.player
# skipping com.yakovlevegor.DroidRec
# skipping com.perflyst.twire
# skipping com.lighttigerxiv.simple.mp
# skipping com.atul.musicplayer
# skipping rocks.mucke
# skipping org.y20k.transistor
# skipping net.sourceforge.kid3
# skipping com.zionhuang.music
# skipping com.vladpen.cams
# skipping site.leos.apps.lespas
# skipping com.kounex.obsBlade
# skipping org.oxycblt.auxio
# skipping org.hzontal.tellaFOSS
# skipping amirz.dngprocessor
# skipping com.kanedias.vanilla.lyrics
# skipping org.piwigo.android
# skipping com.mustupid.pitch_pipe
# skipping com.mustupid.metronome
# skipping fr.jakse.raphael.simpleprotocolplayer
# skipping org.thiolliere.youtubestream
# skipping click.dummer.have_radiosion
# skipping com.adam.aslfms
# skipping org.savapage.android.print
# skipping io.github.tjg1.nori
# skipping net.currit.tonality
# skipping com.jim.sharetocomputer
# skipping org.nv95.openmanga
# skipping com.lun.chin.aicamera
# skipping com.pixiv.muzei.pixivsource
# skipping ch.blinkenlights.android.vanillaplug
# skipping community.peers.internetradio
# skipping protect.videoeditor
# skipping com.sahdeepsingh.Bop
# skipping eu.pretix.pretixdroid
# skipping org.handmadeideas.chordreader
# skipping es.esy.CosyDVR
# skipping com.example.muzei.muzeiapod
# skipping org.secuso.privacyfriendlytapemeasure
# skipping net.ddns.mlsoftlaberge.trycorder
# skipping com.wangdaye.mysplash
# skipping com.shkmishra.lyrically
# skipping com.antoniotari.reactiveampacheapp
# skipping de.uwepost.android.deltacam
# skipping com.iven.musicplayergo
# skipping org.mult.daap
# skipping com.ulicae.cinelog
# skipping it.vfsfitvnm.vimusic
# skipping org.xbmc.kodi
# skipping net.turtton.ytalarm
# skipping com.dosse.airpods
# skipping tech.waelk.radioactive.metronome
# skipping com.shabinder.spotiflyer
# skipping com.leestarb.fourthtools
# skipping com.danhasting.radar
# skipping troop.com.freedcam
# skipping com.abh80.smartedge
# skipping org.sensors2.osc
# skipping wseemann.media.romote
# skipping org.musicbrainz.picard.barcodescanner
# skipping org.xbmc.kore
# skipping com.workingagenda.democracydroid
# skipping fr.nuage.souvenirs
# skipping phone.vishnu.dialogmusicplayer
# skipping org.billthefarmer.shorty
# skipping org.sensors2.pd
# skipping org.billthefarmer.melodeon
# skipping de.fff.ccgt
# skipping org.billthefarmer.accordion
# skipping com.cliambrown.easynoise
# skipping me.echeung.moemoekyun.fdroid
# skipping miccah.mpvremote
# skipping com.danefinlay.ttsutil
# skipping org.yausername.dvd
# skipping de.yaacc
# skipping com.mkulesh.onpc
# skipping co.appreactor.news
# skipping agrigolo.chubbyclick
# skipping dev.datlag.burningseries
# skipping de.msal.muzei.nationalgeographic
# skipping de.danoeh.antennapod
# skipping it.danieleverducci.ojo
# skipping com.junkfood.seal
# skipping org.y20k.escapepod
# skipping free.rm.skytube.legacy.oss
# skipping audio.funkwhale.ffa
# skipping free.rm.skytube.oss
# skipping fm.helio
# skipping se.tube42.drum.android
# skipping eu.kanade.tachiyomi
# skipping org.stingle.photos
# skipping net.nurik.roman.muzei
# skipping com.github.ashutoshgngwr.noice
# skipping io.github.muntashirakon.Music
# skipping code.name.monkey.retromusic
# skipping cc.kafuu.bilidownload
# skipping agersant.polaris
# skipping souch.smp
# skipping ro.radioromaniaactualitati.podcasts
# skipping com.redcoracle.episodes
# skipping uk.org.ngo.squeezer
# skipping io.github.gsantner.memetastic
# skipping com.craigd.lmsmaterial.app
# skipping su.sadrobot.yashlang
# skipping org.esteban.piano
# skipping akk.astro.droid.moonphase
# skipping com.harleensahni.android.mbr
# skipping de.onyxbits.photobookmark
# skipping com.github.nutomic.controldlna
# skipping com.pheelicks.visualizer
# skipping com.f0x.eddymalou
# skipping org.peterbaldwin.client.android.vlcremote
# skipping com.example.sshtry
# skipping com.boztalay.puppyframeuid
# skipping com.timvdalen.gizmooi
# skipping com.jlyr
# skipping de.Cherubin7th.blackscreenpresentationremote
# skipping fm.libre.droid
# skipping de.jurihock.voicesmith
# skipping org.coolfrood.mytronome
# skipping ch.hsr.eyecam
# skipping urbanstew.RehearsalAssistant
# skipping com.gracecode.android.presentation
# skipping com.googlecode.eyesfree.espeak
# skipping com.nesswit.galbijjimsearcher
# skipping com.elsewhat.android.currentwallpaper
# skipping com.lightbox.android.camera
# skipping org.okfn.pod
# skipping de.laxu.apps.nachtlagerdownloader
# skipping com.danielme.muspyforandroid
# skipping com.orphan.amplayer
# skipping com.nauj27.android.colorpicker
# skipping uk.ac.cam.cl.dtg.android.barcodebox
# skipping org.mythdroid
# skipping com.zaren
# skipping org.beide.droidgain
# skipping dk.nindroid.rss
# skipping com.intervigil.micdroid
# skipping com.andrew.apollo
# skipping com.dngames.mobilewebcam
# skipping org.ncrmnt.nettts
# skipping sonoroxadc.garethmurfin.co.uk
# skipping jp.co.kayo.android.localplayer.ds.ampache
# skipping net.avs234
# skipping jp.co.kayo.android.localplayer
# skipping org.xbmc.android.remote
# skipping com.proch.practicehub
# skipping net.codechunk.speedofsound
# skipping com.midisheetmusic
# skipping eu.domob.anacam
# skipping org.sickstache
# skipping com.ihunda.android.binauralbeat
# skipping org.ardour
# skipping org.gitorious.jamesjrh.isokeys
# skipping org.gmote.client.android
# skipping net.jjc1138.android.scrobbler
# skipping com.roozen.SoundManagerv2
# skipping com.gcstar.scanner
# skipping com.nolanlawson.chordreader
# skipping net.micode.soundrecorder
# skipping com.templaro.opsiz.aka
# skipping org.tunesremote
# skipping cc.co.eurdev.urecorder
# skipping com.piwi.stickeroid
# skipping ee.ioc.phon.android.speak
# skipping com.holoplay
# skipping de.kromke.andreas.mediascanner
# skipping com.mendhak.sheepyhorn
# skipping de.mathema.privacyblur
# skipping com.tioui.opensound
# skipping info.schnatterer.nusic
# skipping com.dimowner.audiorecorder
# skipping com.asdoi.quicktiles
# skipping eu.dorfbrunnen.momkin
# skipping com.bri1.soundbored2
# skipping fr.mobdev.peertubelive
# skipping eu.mrogalski.saidit
# skipping com.genonbeta.TrebleShot
# skipping com.m3sv.plainupnp
# skipping cc.echonet.coolmicapp
# skipping ua.gardenapple.trylbry
# skipping ca.ramzan.virtuosity
# skipping eu.pretix.pretixscan.droid
# skipping com.funkymuse.aurora
# skipping org.easyear
# skipping org.droidupnp
# skipping com.dosse.bwentrain.androidPlayer
# skipping fr.nihilus.music
# skipping com.crazylegend.subhub
# skipping me.austinhuang.instagrabber
# skipping me.wenxinwang.pulsedroidrtp
# skipping com.kanedias.vanilla.metadata
# skipping io.lbry.browser
# skipping org.helllabs.android.xmp
# skipping com.ammar.wallflow
# skipping app.olauncher
# skipping io.github.doubi88.slideshowwallpaper
# skipping com.jkuester.unlauncher
# skipping de.markusfisch.android.pielauncher
# skipping cat.mvmike.minimalcalendarwidget
# skipping app.mlauncher
# skipping org.jwz.xscreensaver
# skipping com.donnnno.arcticons
# skipping com.donnnno.arcticons.you
# skipping com.donnnno.arcticons.light
# skipping de.mm20.launcher2.release
# skipping com.example.forgottenumbrella.cardboardmuseum
# skipping com.alaory.wallmewallpaper
# skipping website.leifs.delta.foss
# ...
# Hitting package com.nolanlawson.logcat (https://f-droid.org/en/packages/com.nolanlawson.logcat/)
# Hitting package info.guardianproject.checkey (https://f-droid.org/en/packages/info.guardianproject.checkey/)
# Hitting package jp.sblo.pandora.aGrep (https://f-droid.org/en/packages/jp.sblo.pandora.aGrep/)
# Hitting package com.littlebytesofpi.pylauncher (https://f-droid.org/en/packages/com.littlebytesofpi.pylauncher/)
# Hitting package com.nilhcem.hostseditor (https://f-droid.org/en/packages/com.nilhcem.hostseditor/)
# Hitting package in.indiandragon.shellshock.shellshockvulnerabilityscan (https://f-droid.org/en/packages/in.indiandragon.shellshock.shellshockvulnerabilityscan/)
# Hitting package net.debian.debiandroid (https://f-droid.org/en/packages/net.debian.debiandroid/)
# Saving CSV...
# Hitting package rs.pedjaapps.alogcatroot.app (https://f-droid.org/en/packages/rs.pedjaapps.alogcatroot.app/)
# Hitting package com.mobiperf (https://f-droid.org/en/packages/com.mobiperf/)
# Hitting package org.ndeftools.boilerplate (https://f-droid.org/en/packages/org.ndeftools.boilerplate/)
# Hitting package uobikiemukot.yaft (https://f-droid.org/en/packages/uobikiemukot.yaft/)
# Hitting package com.lonepulse.travisjr (https://f-droid.org/en/packages/com.lonepulse.travisjr/)
# Hitting package com.bytehamster.changelog (https://f-droid.org/en/packages/com.bytehamster.changelog/)
# Hitting package jp.forkhub (https://f-droid.org/en/packages/jp.forkhub/)
# Hitting package com.bmco.cratesiounofficial (https://f-droid.org/en/packages/com.bmco.cratesiounofficial/)
# Hitting package com.nomadlabs.labcoat.deeplinks (https://f-droid.org/en/packages/com.nomadlabs.labcoat.deeplinks/)
# Hitting package com.wrmndfzzy.atomize (https://f-droid.org/en/packages/com.wrmndfzzy.atomize/)
# Saving CSV...
# Hitting package de.sensebox.blockly (https://f-droid.org/en/packages/de.sensebox.blockly/)
# Hitting package com.afollestad.nocknock (https://f-droid.org/en/packages/com.afollestad.nocknock/)
# Hitting package io.github.lonamiwebs.stringlate (https://f-droid.org/en/packages/io.github.lonamiwebs.stringlate/)
# Hitting package me.johnmh.boogdroid (https://f-droid.org/en/packages/me.johnmh.boogdroid/)
# Hitting package in.andres.kandroid (https://f-droid.org/en/packages/in.andres.kandroid/)
# Hitting package com.fastaccess.github.libre (https://f-droid.org/en/packages/com.fastaccess.github.libre/)
# Hitting package com.evenement.encapsulation (https://f-droid.org/en/packages/com.evenement.encapsulation/)
# Hitting package fr.librinfo.evecontrol2 (https://f-droid.org/en/packages/fr.librinfo.evecontrol2/)
# Hitting package click.dummer.UartSmartwatch (https://f-droid.org/en/packages/click.dummer.UartSmartwatch/)
# Hitting package jackpal.androidterm (https://f-droid.org/en/packages/jackpal.androidterm/)
# Saving CSV...
# Hitting package nodom.darkfm.inventoryguimobile (https://f-droid.org/en/packages/nodom.darkfm.inventoryguimobile/)
# Hitting package community.peers.license (https://f-droid.org/en/packages/community.peers.license/)
# Hitting package de.k3b.android.contentproviderhelper (https://f-droid.org/en/packages/de.k3b.android.contentproviderhelper/)
# Hitting package com.tmendes.dadosd (https://f-droid.org/en/packages/com.tmendes.dadosd/)
# Hitting package com.cleveroad.sample (https://f-droid.org/en/packages/com.cleveroad.sample/)
# Hitting package org.dyndns.sven_ola.debian_kit (https://f-droid.org/en/packages/org.dyndns.sven_ola.debian_kit/)
# Hitting package org.kde.necessitas.ministro (https://f-droid.org/en/packages/org.kde.necessitas.ministro/)
# Hitting package com.enrico.filemanager (https://f-droid.org/en/packages/com.enrico.filemanager/)
# Hitting package org.ligi.blexplorer (https://f-droid.org/en/packages/org.ligi.blexplorer/)
# Hitting package uk.co.ashtonbrsc.android.intentintercept (https://f-droid.org/en/packages/uk.co.ashtonbrsc.android.intentintercept/)
# Saving CSV...
# Hitting package com.bec3.mobilite (https://f-droid.org/en/packages/com.bec3.mobilite/)
# Hitting package me.shrimadhavuk.numselapp (https://f-droid.org/en/packages/me.shrimadhavuk.numselapp/)
# Hitting package net.bluetoothviewer (https://f-droid.org/en/packages/net.bluetoothviewer/)
# Hitting package com.jbirdvegas.mgerrit (https://f-droid.org/en/packages/com.jbirdvegas.mgerrit/)
# Hitting package com.matoski.adbm (https://f-droid.org/en/packages/com.matoski.adbm/)
# Hitting package com.foxdebug.acode (https://f-droid.org/en/packages/com.foxdebug.acode/)
# Hitting package com.codelv.inventory (https://f-droid.org/en/packages/com.codelv.inventory/)
# Hitting package com.maxistar.textpad (https://f-droid.org/en/packages/com.maxistar.textpad/)
# Hitting package de.markusfisch.android.shadereditor (https://f-droid.org/en/packages/de.markusfisch.android.shadereditor/)
# Hitting package com.sweak.qralarm (https://f-droid.org/en/packages/com.sweak.qralarm/)
# Saving CSV...
# Hitting package com.termux.nix (https://f-droid.org/en/packages/com.termux.nix/)
# Hitting package com.madlonkay.orgro (https://f-droid.org/en/packages/com.madlonkay.orgro/)
# Hitting package juloo.keyboard2 (https://f-droid.org/en/packages/juloo.keyboard2/)
# Hitting package com.github.ttl.manager (https://f-droid.org/en/packages/com.github.ttl.manager/)
# Hitting package fr.ralala.hexviewer (https://f-droid.org/en/packages/fr.ralala.hexviewer/)
# Hitting package com.blacksquircle.ui (https://f-droid.org/en/packages/com.blacksquircle.ui/)
# Hitting package de.storchp.fdroidbuildstatus (https://f-droid.org/en/packages/de.storchp.fdroidbuildstatus/)
# Hitting package priv.wh201906.serialtest (https://f-droid.org/en/packages/priv.wh201906.serialtest/)
# Hitting package com.activitymanager (https://f-droid.org/en/packages/com.activitymanager/)
# Hitting package ru.sash0k.bluetooth_terminal (https://f-droid.org/en/packages/ru.sash0k.bluetooth_terminal/)
# Saving CSV...
# Hitting package tk.hack5.treblecheck (https://f-droid.org/en/packages/tk.hack5.treblecheck/)
# Hitting package org.godotengine.editor.v4 (https://f-droid.org/en/packages/org.godotengine.editor.v4/)
# Hitting package de.k3b.android.intentintercept (https://f-droid.org/en/packages/de.k3b.android.intentintercept/)
# Hitting package cl.coders.faketraveler (https://f-droid.org/en/packages/cl.coders.faketraveler/)
# Hitting package dev.yashgarg.qbit (https://f-droid.org/en/packages/dev.yashgarg.qbit/)
# Hitting package com.termux.styling (https://f-droid.org/en/packages/com.termux.styling/)
# Hitting package org.gnu.emacs (https://f-droid.org/en/packages/org.gnu.emacs/)
# Hitting package nl.tsmeets.todotree (https://f-droid.org/en/packages/nl.tsmeets.todotree/)
# Hitting package org.godotengine.editor.v3 (https://f-droid.org/en/packages/org.godotengine.editor.v3/)
# Hitting package com.nesbox.tic (https://f-droid.org/en/packages/com.nesbox.tic/)
# Saving CSV...
# Hitting package com.manichord.mgit (https://f-droid.org/en/packages/com.manichord.mgit/)
# Hitting package ooo.akito.webmon (https://f-droid.org/en/packages/ooo.akito.webmon/)
# Hitting package com.sunilpaulmathew.translator (https://f-droid.org/en/packages/com.sunilpaulmathew.translator/)
# Hitting package marto.rtl_tcp_andro (https://f-droid.org/en/packages/marto.rtl_tcp_andro/)
# Hitting package im.nfc.nfsee (https://f-droid.org/en/packages/im.nfc.nfsee/)
# Hitting package org.segin.ttleditor (https://f-droid.org/en/packages/org.segin.ttleditor/)
# Hitting package org.segin.bfinterpreter (https://f-droid.org/en/packages/org.segin.bfinterpreter/)
# Hitting package com.android.adbkeyboard (https://f-droid.org/en/packages/com.android.adbkeyboard/)
# Hitting package de.eidottermihi.raspicheck (https://f-droid.org/en/packages/de.eidottermihi.raspicheck/)
# Hitting package tech.platypush.platypush (https://f-droid.org/en/packages/tech.platypush.platypush/)
# Saving CSV...
# Hitting package org.gittner.osmbugs (https://f-droid.org/en/packages/org.gittner.osmbugs/)
# Hitting package com.nathaniel.motus.umlclasseditor (https://f-droid.org/en/packages/com.nathaniel.motus.umlclasseditor/)
# Hitting package io.github.pd4d10.gittouch (https://f-droid.org/en/packages/io.github.pd4d10.gittouch/)
# Hitting package com.releasestandard.scriptmanager (https://f-droid.org/en/packages/com.releasestandard.scriptmanager/)
# Hitting package com.ruesga.rview (https://f-droid.org/en/packages/com.ruesga.rview/)
# Hitting package fr.xgouchet.packageexplorer (https://f-droid.org/en/packages/fr.xgouchet.packageexplorer/)
# Hitting package com.mattmaniak.queueToDo (https://f-droid.org/en/packages/com.mattmaniak.queueToDo/)
# Hitting package io.github.randomfilemaker (https://f-droid.org/en/packages/io.github.randomfilemaker/)
# Hitting package com.example.booklistingapk (https://f-droid.org/en/packages/com.example.booklistingapk/)
# Hitting package io.github.ismywebsiteup (https://f-droid.org/en/packages/io.github.ismywebsiteup/)
# Saving CSV...
# Hitting package com.rascarlo.aurdroid (https://f-droid.org/en/packages/com.rascarlo.aurdroid/)
# Hitting package de.grobox.appbundlereporter (https://f-droid.org/en/packages/de.grobox.appbundlereporter/)
# Hitting package io.github.hasheazy (https://f-droid.org/en/packages/io.github.hasheazy/)
# Hitting package com.garyodernichts.downgrader (https://f-droid.org/en/packages/com.garyodernichts.downgrader/)
# Hitting package eu.roggstar.getmitokens (https://f-droid.org/en/packages/eu.roggstar.getmitokens/)
# Hitting package com.lindevhard.android.raspfinder (https://f-droid.org/en/packages/com.lindevhard.android.raspfinder/)
# Hitting package io.neurolab (https://f-droid.org/en/packages/io.neurolab/)
# Hitting package org.getdisconnected.libreipsum (https://f-droid.org/en/packages/org.getdisconnected.libreipsum/)
# Hitting package io.github.easyintent.quickref (https://f-droid.org/en/packages/io.github.easyintent.quickref/)
# Hitting package com.rascarlo.arch.packages (https://f-droid.org/en/packages/com.rascarlo.arch.packages/)
# Saving CSV...
# Hitting package nl.patrickkostjens.kandroid (https://f-droid.org/en/packages/nl.patrickkostjens.kandroid/)
# Hitting package com.jakewharton.sdksearch (https://f-droid.org/en/packages/com.jakewharton.sdksearch/)
# Hitting package click.dummer.textthing (https://f-droid.org/en/packages/click.dummer.textthing/)
# Hitting package com.termux.boot (https://f-droid.org/en/packages/com.termux.boot/)
# Hitting package com.wesaphzt.privatelocation (https://f-droid.org/en/packages/com.wesaphzt.privatelocation/)
# Hitting package exa.lnx.a (https://f-droid.org/en/packages/exa.lnx.a/)
# Hitting package com.gh4a (https://f-droid.org/en/packages/com.gh4a/)
# Hitting package org.echoline.drawterm (https://f-droid.org/en/packages/org.echoline.drawterm/)
# Hitting package taco.scoop (https://f-droid.org/en/packages/taco.scoop/)
# Hitting package eu.dfdx.jslab (https://f-droid.org/en/packages/eu.dfdx.jslab/)
# Saving CSV...
# Hitting package com.catalin.css_px_converter (https://f-droid.org/en/packages/com.catalin.css_px_converter/)
# Hitting package net.sourceforge.x11basic (https://f-droid.org/en/packages/net.sourceforge.x11basic/)
# Hitting package com.vsmartcard.acardemulator (https://f-droid.org/en/packages/com.vsmartcard.acardemulator/)
# Hitting package com.trianguloy.numericriddlegenerator (https://f-droid.org/en/packages/com.trianguloy.numericriddlegenerator/)
# Hitting package com.fredhappyface.brainf (https://f-droid.org/en/packages/com.fredhappyface.brainf/)
# Hitting package com.trianguloy.isUserAMonkey (https://f-droid.org/en/packages/com.trianguloy.isUserAMonkey/)
# Hitting package com.trianguloy.adnihilation (https://f-droid.org/en/packages/com.trianguloy.adnihilation/)
# Hitting package com.termux.tasker (https://f-droid.org/en/packages/com.termux.tasker/)
# Hitting package com.biotstoiq.cryptix (https://f-droid.org/en/packages/com.biotstoiq.cryptix/)
# Hitting package io.kubenav.kubenav (https://f-droid.org/en/packages/io.kubenav.kubenav/)
# Saving CSV...
# Hitting package de.mw136.tonuino (https://f-droid.org/en/packages/de.mw136.tonuino/)
# Hitting package io.muetsch.anchrandroid (https://f-droid.org/en/packages/io.muetsch.anchrandroid/)
# Hitting package com.fredhappyface.fhcode (https://f-droid.org/en/packages/com.fredhappyface.fhcode/)
# Hitting package com.termux.window (https://f-droid.org/en/packages/com.termux.window/)
# Hitting package com.termux (https://f-droid.org/en/packages/com.termux/)
# Hitting package com.termux.api (https://f-droid.org/en/packages/com.termux.api/)
# Hitting package wtf.technodisaster.tldr (https://f-droid.org/en/packages/wtf.technodisaster.tldr/)
# Hitting package com.asdoi.quicktiles (https://f-droid.org/en/packages/com.asdoi.quicktiles/)
# Hitting package de.syss.MifareClassicTool (https://f-droid.org/en/packages/de.syss.MifareClassicTool/)
# Hitting package tech.ula (https://f-droid.org/en/packages/tech.ula/)
# Saving CSV...
# Hitting package com.github.sryze.wirebug (https://f-droid.org/en/packages/com.github.sryze.wirebug/)
# Hitting package de.csicar.ning (https://f-droid.org/en/packages/de.csicar.ning/)
# Hitting package com.team242.robozzle (https://f-droid.org/en/packages/com.team242.robozzle/)
# Hitting package com.adonai.manman (https://f-droid.org/en/packages/com.adonai.manman/)
# Hitting package com.kpstv.xclipper (https://f-droid.org/en/packages/com.kpstv.xclipper/)
# Hitting package de.zieren.rot13 (https://f-droid.org/en/packages/de.zieren.rot13/)
# Hitting package com.github.mobile (https://f-droid.org/en/packages/com.github.mobile/)
# Hitting package com.notriddle.null_launcer (https://f-droid.org/en/packages/com.notriddle.null_launcer/)
# Hitting package ch.fixme.cowsay (https://f-droid.org/en/packages/ch.fixme.cowsay/)
# Hitting package steele.gerry.dotty (https://f-droid.org/en/packages/steele.gerry.dotty/)
# Saving CSV...
# Hitting package com.primavera.arduino.listener (https://f-droid.org/en/packages/com.primavera.arduino.listener/)
# Hitting package com.github.andlyticsproject (https://f-droid.org/en/packages/com.github.andlyticsproject/)
# Hitting package org.jessies.dalvikexplorer (https://f-droid.org/en/packages/org.jessies.dalvikexplorer/)
# Hitting package com.bretternst.URLazy (https://f-droid.org/en/packages/com.bretternst.URLazy/)
# Hitting package org.servDroid.web (https://f-droid.org/en/packages/org.servDroid.web/)
# Hitting package com.dconstructing.cooper (https://f-droid.org/en/packages/com.dconstructing.cooper/)
# Hitting package org.jtb.httpmon (https://f-droid.org/en/packages/org.jtb.httpmon/)
# Hitting package com.gokhanmoral.stweaks.app (https://f-droid.org/en/packages/com.gokhanmoral.stweaks.app/)
# Hitting package it.sineo.android.noFrillsCPUClassic (https://f-droid.org/en/packages/it.sineo.android.noFrillsCPUClassic/)
# Hitting package jp.ksksue.app.terminal (https://f-droid.org/en/packages/jp.ksksue.app.terminal/)
# Saving CSV...
# Hitting package org.projectvoodoo.screentestpatterns (https://f-droid.org/en/packages/org.projectvoodoo.screentestpatterns/)
# Hitting package dk.andsen.asqlitemanager (https://f-droid.org/en/packages/dk.andsen.asqlitemanager/)
# Hitting package com.myopicmobile.textwarrior.android (https://f-droid.org/en/packages/com.myopicmobile.textwarrior.android/)
# Hitting package net.momodalo.app.vimtouch (https://f-droid.org/en/packages/net.momodalo.app.vimtouch/)
# Hitting package aws.apps.androidDrawables (https://f-droid.org/en/packages/aws.apps.androidDrawables/)
# Hitting package org.nathan.jf.build.prop.editor (https://f-droid.org/en/packages/org.nathan.jf.build.prop.editor/)
# Hitting package com.jecelyin.editor (https://f-droid.org/en/packages/com.jecelyin.editor/)
# Hitting package com.kkinder.charmap (https://f-droid.org/en/packages/com.kkinder.charmap/)
# Hitting package com.threedlite.urforms (https://f-droid.org/en/packages/com.threedlite.urforms/)
# Hitting package com.valleytg.oasvn.android (https://f-droid.org/en/packages/com.valleytg.oasvn.android/)
# Saving CSV...
# Hitting package mobi.cyann.nstools (https://f-droid.org/en/packages/mobi.cyann.nstools/)
# Hitting package org.madore.android.unicodeMap (https://f-droid.org/en/packages/org.madore.android.unicodeMap/)
# Hitting package org.jtb.alogcat (https://f-droid.org/en/packages/org.jtb.alogcat/)
# Done

# %%
with open("fdroid.html", 'r') as html_file:
    soup = BeautifulSoup(html_file, features='lxml')
    example = get_application_info_from_package_page(soup)
example
# Out:
# {'author': 'SECUSO - Security Usability Society',
#  'author_contact': 'mailto:contact@secuso.org?subject=F-Droid - Free and Open Source Android App Repository%20on%20',
#  'license': 'GNU General Public License v3.0 or later',
#  'license_page': 'https://www.gnu.org/licenses/gpl-3.0-standalone.html',
#  'website': 'https://www.secuso.informatik.tu-darmstadt.de/index.php?id=11404&L=0',
#  'issue_tracker': 'https://github.com/SecUSo/privacy-friendly-tape-measure/issues',
#  'source_code': 'https://github.com/SecUSo/privacy-friendly-tape-measure',
#  'build_metadata': 'https://gitlab.com/fdroid/fdroiddata/tree/master/metadata/org.secuso.privacyfriendlytapemeasure.yml'}
